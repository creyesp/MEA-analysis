# %% [markdown]
# # Preprocessing
# # Create a structured HDF5 file

# %%
import os
import sys
sys.path.append('../src')

import h5py
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from mealib.utils import check_directory

# %%
sampling_rate = 20000
experiment_name = '2018-01-25'
# experiment_name = '2018-04-18'

# %% [markdown]
# # HDF5

# %%
source_file = '../data/raw_data/'+experiment_name+'/'+experiment_name+'_merged.hdf5'
timestamps_raw = h5py.File(source_file, 'r')

event_list = pd.read_csv('../data/sync/'+experiment_name+'/event_list/event_list_'+experiment_name+'.csv')
event_list['tail'] = event_list['start_event'][1:].values.tolist() + event_list['end_event'][-1:].values.tolist()
event_list.replace(np.nan, '', inplace=True)
event_list
# Out:
#         file  presentation_number  n_frames  start_event  end_event  \
# 0                               0         0            0    6038432
# 1    000.txt                    1     18613      6038431   12268075
# 2    001.txt                    2      2100     12437221   13140116
# 3    002.txt                    2      2100     13220111   13923006
# 4    003.txt                    2      2100     14003000   14705895
# 5    004.txt                    2      2100     14785890   15488784
# 6    005.txt                    2      2100     15568779   16271674
# 7    006.txt                    2      2100     16351668   17054563
# 8    007.txt                    2      2100     17134558   17837453
# 9    008.txt                    2      2100     17917447   18620342
# 10   009.txt                    2      2100     18700337   19403232
# 11   010.txt                    2      2100     19483226   20186121
# 12   011.txt                    2      2100     20266116   20969011
# 13   012.txt                    2      2100     21049005   21751900
# 14   013.txt                    2      2100     21831895   22534790
# 15   014.txt                    2      2103     22614784   23318683
# 16   015.txt                    2      2100     23398678   24101573
# 17   016.txt                    2      2100     24181567   24884462
# 18   017.txt                    2      2100     24964457   25667352
# 19   018.txt                    2      2100     25747346   26450241
# 20   019.txt                    2      2100     26530236   27233131
# 21   020.txt                    2      2100     27313125   28016020
# 22   021.txt                    2      2100     28096015   28798909
# 23   022.txt                    3     72001     29138737   53238286
# 24   023.txt                    4      1800     53396735   53999217
# 25                              4      1802     53999216   54602366
# 26                              4      1800     54602365   55204847
# 27                              4      1800     55204846   55807327
# 28                              4      1800     55807326   56409808
# 29                              4      1800     56409807   57012288
# ..       ...                  ...       ...          ...        ...
# 121                             8      1800    112413600  113016080
# 122                             8      1800    113016079  113618560
# 123                             8      1800    113618559  114221039
# 124                             8      1800    114221038  114823518
# 125                             8      1800    114823517  115425997
# 126                             8      1800    115425996  116028476
# 127                             8      1800    116028475  116630955
# 128                             8      1800    116630954  117233434
# 129  028.txt                    9      1800    117314196  117916676
# 130                             9      1800    117916675  118519155
# 131                             9      1800    118519154  119121634
# 132                             9      1800    119121633  119724113
# 133                             9      1801    119724112  120326927
# 134                             9      1800    120326926  120929406
# 135                             9      1800    120929405  121531885
# 136                             9      1800    121531884  122134364
# 137                             9      1800    122134363  122736843
# 138                             9      1800    122736842  123339322
# 139                             9      1800    123339321  123941801
# 140                             9      1800    123941800  124544280
# 141                             9      1800    124544279  125146759
# 142                             9      1800    125146758  125749238
# 143                             9      1800    125749237  126351717
# 144                             9      1800    126351716  126954196
# 145                             9      1800    126954195  127556675
# 146                             9      1800    127556674  128159154
# 147                             9      1802    128159153  128762302
# 148                             9      1800    128762301  129364781
# 149                             9      1800    129364780  129967259
# 150                            10         0    129967259  130063999
#
#      event_duration  inter_event_duration              protocol_name  \
# 0         301.92160               0.00000                   scotopic
# 1         311.48220               0.00000                   photopic
# 2          35.14475               8.45730                      chirp
# 3          35.14475               3.99975                      chirp
# 4          35.14475               3.99970                      chirp
# 5          35.14470               3.99975                      chirp
# 6          35.14475               3.99975                      chirp
# 7          35.14475               3.99970                      chirp
# 8          35.14475               3.99975                      chirp
# 9          35.14475               3.99970                      chirp
# 10         35.14475               3.99975                      chirp
# 11         35.14475               3.99970                      chirp
# 12         35.14475               3.99975                      chirp
# 13         35.14475               3.99970                      chirp
# 14         35.14475               3.99975                      chirp
# 15         35.19495               3.99970                      chirp
# 16         35.14475               3.99975                      chirp
# 17         35.14475               3.99970                      chirp
# 18         35.14475               3.99975                      chirp
# 19         35.14475               3.99970                      chirp
# 20         35.14475               3.99975                      chirp
# 21         35.14475               3.99970                      chirp
# 22         35.14470               3.99975                      chirp
# 23       1204.97745              16.99140               checkerboard
# 24         30.12410               7.92245              natural_image
# 25         30.15750               0.00000              natural_image
# 26         30.12410               0.00000              natural_image
# 27         30.12405               0.00000              natural_image
# 28         30.12410               0.00000              natural_image
# 29         30.12405               0.00000              natural_image
# ..              ...                   ...                        ...
# 121        30.12400               0.00000      natural_image_inv_BGA
# 122        30.12405               0.00000      natural_image_inv_BGA
# 123        30.12400               0.00000      natural_image_inv_BGA
# 124        30.12400               0.00000      natural_image_inv_BGA
# 125        30.12400               0.00000      natural_image_inv_BGA
# 126        30.12400               0.00000      natural_image_inv_BGA
# 127        30.12400               0.00000      natural_image_inv_BGA
# 128        30.12400               0.00000      natural_image_inv_BGA
# 129        30.12400               4.03810  natural_image_shuffle_BGA
# 130        30.12400               0.00000  natural_image_shuffle_BGA
# 131        30.12400               0.00000  natural_image_shuffle_BGA
# 132        30.12400               0.00000  natural_image_shuffle_BGA
# 133        30.14075               0.00000  natural_image_shuffle_BGA
# 134        30.12400               0.00000  natural_image_shuffle_BGA
# 135        30.12400               0.00000  natural_image_shuffle_BGA
# 136        30.12400               0.00000  natural_image_shuffle_BGA
# 137        30.12400               0.00000  natural_image_shuffle_BGA
# 138        30.12400               0.00000  natural_image_shuffle_BGA
# 139        30.12400               0.00000  natural_image_shuffle_BGA
# 140        30.12400               0.00000  natural_image_shuffle_BGA
# 141        30.12400               0.00000  natural_image_shuffle_BGA
# 142        30.12400               0.00000  natural_image_shuffle_BGA
# 143        30.12400               0.00000  natural_image_shuffle_BGA
# 144        30.12400               0.00000  natural_image_shuffle_BGA
# 145        30.12400               0.00000  natural_image_shuffle_BGA
# 146        30.12400               0.00000  natural_image_shuffle_BGA
# 147        30.15745               0.00000  natural_image_shuffle_BGA
# 148        30.12400               0.00000  natural_image_shuffle_BGA
# 149        30.12395               0.00000  natural_image_shuffle_BGA
# 150         4.83700               0.00000                       tail
#
#     repetition_name                repeated_frame #repeated_frame       tail
# 0                                                                    6038431
# 1                                                                   12437221
# 2            rep_00                                                 13220111
# 3            rep_01                                                 14003000
# 4            rep_02                                                 14785890
# 5            rep_03                                                 15568779
# 6            rep_04                                                 16351668
# 7            rep_05                                                 17134558
# 8            rep_06                                                 17917447
# 9            rep_07                                                 18700337
# 10           rep_08                                                 19483226
# 11           rep_09                                                 20266116
# 12           rep_10                                                 21049005
# 13           rep_11                                                 21831895
# 14           rep_12                                                 22614784
# 15           rep_13  [23115849 23116184 23116518]               3   23398678
# 16           rep_14                                                 24181567
# 17           rep_15                                                 24964457
# 18           rep_16                                                 25747346
# 19           rep_17                                                 26530236
# 20           rep_18                                                 27313125
# 21           rep_19                                                 28096015
# 22           rep_20                                                 29138737
# 23                                     [32117669]               1   53396735
# 24           rep_00                                                 53999216
# 25           rep_01           [54428652 54428987]               2   54602365
# 26           rep_02                                                 55204846
# 27           rep_03                                                 55807326
# 28           rep_04                                                 56409807
# 29           rep_05                                                 57012287
# ..              ...                           ...             ...        ...
# 121          rep_13                                                113016079
# 122          rep_14                                                113618559
# 123          rep_15                                                114221038
# 124          rep_16                                                114823517
# 125          rep_17                                                115425996
# 126          rep_18                                                116028475
# 127          rep_19                                                116630954
# 128          rep_20                                                117314196
# 129          rep_00                                                117916675
# 130          rep_01                                                118519154
# 131          rep_02                                                119121633
# 132          rep_03                                                119724112
# 133          rep_04                   [120927399]               1  120326926
# 134          rep_05                                                120929405
# 135          rep_06                                                121531884
# 136          rep_07                                                122134363
# 137          rep_08                                                122736842
# 138          rep_09                                                123339321
# 139          rep_10                                                123941800
# 140          rep_11                                                124544279
# 141          rep_12                                                125146758
# 142          rep_13                                                125749237
# 143          rep_14                                                126351716
# 144          rep_15                                                126954195
# 145          rep_16                                                127556674
# 146          rep_17                                                128159153
# 147          rep_18         [129013336 129013671]               2  128762301
# 148          rep_19                                                129364780
# 149          rep_20                                                129967259
# 150               0                                                130063999
#
# [151 rows x 12 columns]

# %%
output_file = '../data/structured_data/structured_data_'+experiment_name+'_.hdf5'
# !rm $output_file
ts = h5py.File(output_file, 'a')

# %%
for kunit in timestamps_raw['spiketimes']:
    ts_unit_raw = timestamps_raw['spiketimes/'+kunit][:,0]
    for start,end,nframes,name,repetition in event_list[['start_event','tail','n_frames','protocol_name','repetition_name']].values:
        filter_ts = (ts_unit_raw > start)*(ts_unit_raw <= end)
        ds_data = ts_unit_raw[filter_ts] - start
        if repetition:
            ds_name = '/response/{}/{}/{}'.format(name,kunit,repetition)
            ts.create_dataset(ds_name,data=ds_data,dtype=np.int32)
            ts[ds_name].attrs['nframes'] = nframes
        else:
            ds_name = '/response/{}/{}'.format(name,kunit)
            ts.create_dataset(ds_name,data=ds_data,dtype=np.int32)
            ts[ds_name].attrs['nframes'] = nframes
        ts_unit_raw = ts_unit_raw[~filter_ts]

# %%
for presentn, start,end,name,repetition in event_list[['presentation_number','start_event','end_event','protocol_name','repetition_name']].values:
    ts['/response/'+name].attrs['start_time'] = start
    ts['/response/'+name].attrs['end_time'] = end
    ts['/response/'+name].attrs['duration'] = (end-start)/sampling_rate
    ts['/response/'+name].attrs['sample_rate'] = sampling_rate
    ts['/response/'+name].attrs['presentation_number'] = presentn

# %% [markdown]
# ## Set Stimuli

# %%
stim_file = '../data/stim/fullfiledchirp.txt'
stim_name = 'chirp'
stimulus = np.loadtxt(stim_file)
ts.create_dataset('/stimulus/chirp',data=stimulus,dtype=np.float32)
# Out:
# <HDF5 dataset "chirp": shape (2101,), type "<f4">

# %%
wn_file = '../data/stim/checkerboard/stim_2018-01-25.hdf5'
with h5py.File(wn_file,'r') as wn: 
    swn = ts.create_dataset('/stimulus/checkerboard', data=wn['checkerboard'], dtype=np.uint8,chunks=(35,35,1,1),compression="gzip")
    swn.attrs['sample_rate'] = 60.0
    swn.attrs['title'] = 'White noise'

# %% [markdown]
# ## Set sync time

# %%
for kidx,(start,name,repetition) in enumerate(event_list[['start_event','protocol_name','repetition_name']].values):
    sync_file = '../data/sync/'+experiment_name+'/event_list/times/{:03d}.txt'.format(kidx)
    ds_sync = np.loadtxt(sync_file) - start
    
    if repetition:
        ds_name = '/sync/{}/{}'.format(name,repetition)
        ts.create_dataset(ds_name,data=ds_sync,dtype=np.int32) 
        ts[ds_name].attrs['start'] = start
        ts[ds_name].attrs['col_name'] = 'start_frame,end_frame'
    else:
        ds_name = '/sync/{}'.format(name)
        ts.create_dataset(ds_name,data=ds_sync,dtype=np.int32)
        ts[ds_name].attrs['start'] = start
        ts[ds_name].attrs['col_name'] = 'start_frame,end_frame'
# Out:
# /home/cesar/Software/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:3: UserWarning: loadtxt: Empty input file: "../data/sync/2018-01-25/event_list/times/150.txt"
#   app.launch_new_instance()

# %%
ts.flush()
ts.close()
